# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushshivugautam2007-code/Python/blob/main/Practical_2_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create an empty list
shopping_list = []
print("Initiaally, the shopping list is: ")
print(shopping_list)
# Out:
# Initiaally, the shopping list is:
# []

# %%
#Now store the number of items in shopping list: Watch, laptop, shoes, pen, clothes
shopping_list.append("Watch")
shopping_list.append("Laptop")
shopping_list.append("Shoes")
shopping_list.append("Pen")
shopping_list.append("Clothes")
print("\n Shooping List after adding  items: ")
print(shopping_list)
# Out:
#  Shooping List after adding  items:
# ['Watch', 'Laptop', 'Shoes', 'Pen', 'Clothes']

# %%
#Add new item Football to the shopping list
shopping_list.append("Football")
print("\n Shopping list after adding Football: ")
print(shopping_list)
# Out:
#  Shopping list after adding Football:
# ['Watch', 'Laptop', 'Shoes', 'Pen', 'Clothes', 'Football']

# %%
#Print the last item from the shopping list
last_item = shopping_list[-1]
print("\n Last item from the hopping list: ")
print(last_item)
# Out:
#  Last item from the hopping list:
# Football

# %%
#Print entire shopping list
print("\n Entire shopping list: ")
for item in shopping_list:

  print(item)
# Out:
#  Entire shopping list:
# Watch
# Laptop
# Shoes
# Pen
# Clothes
# Football

# %%
#Print the important items like laptop and shoes from the shopping list
print("\n Important items: ")
print("1.", shopping_list[1])
print("2.", shopping_list[2])
# Out:
#  Important items:
# 1. Laptop
# 2. Shoes

# %%
#Change the item: Instead of pen now I want to buy notebook
print("\n Before changing  Pen: ")
print(shopping_list)
shopping_list[3] = "Notebook"
print("\n After changing  pen to notebook: ")
print(shopping_list)
# Out:
#  Before changing  Pen:
# ['Watch', 'Laptop', 'Shoes', 'Pen', 'Clothes', 'Football']
#
#  After changing  pen to notebook:
# ['Watch', 'Laptop', 'Shoes', 'Notebook', 'Clothes', 'Football']

# %%
if "Watch" in shopping_list: shopping_list.remove("Shoes")
else: print("'Watch' is not in the shopping list.")
print("\n Final shopping list after deleting the least important items: ")
for item in shopping_list: print(item)
print("\n Total number of items in the shopping list: ")
print(len(shopping_list))
# Out:
#  Final shopping list after deleting the least important items:
# Watch
# Laptop
# Notebook
# Clothes
# Football
#
#  Total number of items in the shopping list:
# 5
