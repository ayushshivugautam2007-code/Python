# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushshivugautam2007-code/Python/blob/main/Practical_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#write and run the small statement - "HELLO! My name is -- and my hobby is --"
print("HELLO! My name is Ayush Gautam and my hobby is playing cricket. ")
# Out:
# HELLO! My name is Ayush Gautam and my hobby is playing cricket.

# %%
#print the comments.
print("Hello , Python")
# Out:
# Hello , Python

# %%
#Display integer, float, string, boolean.
Integer_value = 20
Float_value = 2.5
String_value = "Ayush Gautam"
Boolean_value = False
print("Integer: ", Integer_value)
print("Float: ", Float_value)
print("String: ", String_value)
print("Boolean: ", Boolean_value)
# Out:
# Integer:  20
# Float:  2.5
# String:  Ayush Gautam
# Boolean:  False

# %%
#Convert float to integer, string to integer, boolean to integer.
float_value = 2.5
integer_value = int(float_value)
print("float to Integer: ", integer_value)
string_value = 3
integer_value - int(string_value)
print("String to Integer: ", integer_value)
Boolean_value = False
integer_value = int(Boolean_value)
print("Boolean to Integer: ", integer_value)
# Out:
# float to Integer:  2
# String to Integer:  2
# Boolean to Integer:  0

# %%
# Provide the simple operations performed in the calculator (addition, subtraction, multiplacation, divison).
a = 20; b = 5;
print("Addition: ", a + b)
print("Subtraction: ", a - b)
print("Multiplication: ", a * b)
print("Divison: ", a / b)
# Out:
# Addition:  25
# Subtraction:  15
# Multiplication:  100
# Divison:  4.0

# %%
my_list = []

# %%
#Write an expression that calculates how many hours there are in 160 minutes
minutes = 160;
hours = minutes / 60;
print("Hours in 160 minutes: ", hours)
# Out:
# Hours in 160 minutes:  2.6666666666666665
